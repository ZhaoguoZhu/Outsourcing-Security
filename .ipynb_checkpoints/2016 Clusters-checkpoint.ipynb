# %%
from sentence_transformers import SentenceTransformer
from sklearn.cluster import AgglomerativeClustering
import numpy as np

from gensim.models import Word2Vec
import nltk
import numpy as np
from sklearn.cluster import KMeans
from sklearn import cluster
from sklearn import metrics
from sklearn.decomposition import PCA
from scipy.cluster import hierarchy
import re
import matplotlib.pyplot as plt
import pandas as pd

import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import random
from sklearn.decomposition import LatentDirichletAllocation

# %%
embedder = SentenceTransformer('distilroberta-base-paraphrase-v1')
df = pd.read_excel("2016.xlsx")
df = df.fillna(method="ffill")

# %%
sentence = []
for index, row in df.iterrows():
    sentence.append(row['Description'])

# %%
corpus_embeddings = embedder.encode(sentence)
corpus_embeddings = corpus_embeddings /  np.linalg.norm(corpus_embeddings, axis=1, keepdims=True)

# %%
Z = hierarchy.linkage(corpus_embeddings, "ward")
dn = hierarchy.dendrogram(Z)
plt.title("Dendrogram")
plt.ylabel("Euclidean distances")
#plt.xlim(0,100)
#plt.ylim(1.2,1.4)
plt.show()

# %%
clustering_model = AgglomerativeClustering(n_clusters=None, affinity='euclidean', linkage='ward', distance_threshold=3) #, affinity='cosine', linkage='average', distance_threshold=0.4)
clustering_model.fit(corpus_embeddings)
cluster_assignment = clustering_model.labels_

clustered_sentences = {}
for sentence_id, cluster_id in enumerate(cluster_assignment):
    if cluster_id not in clustered_sentences:
        clustered_sentences[cluster_id] = []

    clustered_sentences[cluster_id].append(sentence[sentence_id])

'''
for i, cluster in clustered_sentences.items():
    print("Cluster ", i+1)
    print(cluster)
    print("")
'''
# Out:
# '\nfor i, cluster in clustered_sentences.items():\n    print("Cluster ", i+1)\n    print(cluster)\n    print("")\n'

# %%
length = len(clustered_sentences)

# %%
def exe():
    D = {}
    for i,topic in enumerate(LDA.components_):
        x = [count_vect.get_feature_names()[i] for i in topic.argsort()[-10:]]
        for j in x:
            if j in D:
                D[j] += 1
            else: D[j] = 1
    Sorted = sorted(D.items(), key=lambda x: x[1], reverse=True)
    lst = []
    Useless_Word = ["requesting","request", "requests", "copy", "copies", "documents", "document", "information", "informations", "department", "departments", "records", "record", "reports", "report"] 
    for i in Sorted:
        if i[0] in Useless_Word:
            None
        else:
            lst.append(i[0])
        if len(lst) == 3:
            return lst

# %%
for i in range(length):
    count_vect = CountVectorizer(max_df=0.8, min_df=2, stop_words='english')
    doc_term_matrix = count_vect.fit_transform(clustered_sentences[i])
    LDA = LatentDirichletAllocation(n_components=5, random_state=42)
    LDA.fit(doc_term_matrix)
    print(f"Cluster Number {i+1}: ", exe())
    print("Cluster Size: ", len(clustered_sentences[i]))
    print('\n')
# Out:
# Cluster Number 1:  ['list', 'gsa', '1992']
# Cluster Size:  130
#
#
# Cluster Number 2:  ['dod', '2005', 'proposal']
# Cluster Size:  99
#
#
# Cluster Number 3:  ['concerning', 'nsc', 'nsdd']
# Cluster Size:  61
#
#
# Cluster Number 4:  ['referral', 'state', 'president']
# Cluster Size:  201
#
#
# Cluster Number 5:  ['awarded', 'contract', 'regarding']
# Cluster Size:  92
#
#
# Cluster Number 6:  ['responsive', 'hurricane', 'homeland']
# Cluster Size:  92
#
#
# Cluster Number 7:  ['pertaining', 'force', 'air']
# Cluster Size:  195
#
#
# Cluster Number 8:  ['pertaining', 'awarded', 'funded']
# Cluster Size:  26
#
#
# Cluster Number 9:  ['number', 'service', 'war']
# Cluster Size:  96
#
#
# Cluster Number 10:  ['defense', 'awarded', 'dod']
# Cluster Size:  122
#
#
# Cluster Number 11:  ['2001', 'guantanamo', 'concerning']
# Cluster Size:  72
#
#
# Cluster Number 12:  ['related', 'service', 'dod']
# Cluster Size:  154
#
#
# Cluster Number 13:  ['review', 'concerning', 'library']
# Cluster Size:  80
#
#
# Cluster Number 14:  ['pursuant', 'following', '552']
# Cluster Size:  75
#
#
# Cluster Number 15:  ['concerning', 'army', 'regarding']
# Cluster Size:  135
#
#
# Cluster Number 16:  ['pertaining', 'concerning', 'regarding']
# Cluster Size:  44
#
#
# Cluster Number 17:  ['military', 'know', 'service']
# Cluster Size:  39
#
#
# Cluster Number 18:  ['defense', 'dod', 'foia']
# Cluster Size:  159
#
#
# Cluster Number 19:  ['2003', 'iraq', 'concerning']
# Cluster Size:  65
#
#
# Cluster Number 20:  ['know', 'need', 'foia']
# Cluster Size:  74
#
#
# Cluster Number 21:  ['force', '2003', 'defense']
# Cluster Size:  144
#
#
# Cluster Number 22:  ['faction', 'relating', 'paramilitary']
# Cluster Size:  15
#
#
# Cluster Number 23:  ['list', 'contracts', 'dod']
# Cluster Size:  72
#
#
# Cluster Number 24:  ['defense', 'force', 'states']
# Cluster Size:  119
#
#
# Cluster Number 25:  ['following', 'dod', 'defense']
# Cluster Size:  164
#
#
# Cluster Number 26:  ['2003', 'limited', 'memoranda']
# Cluster Size:  71
#
#
# Cluster Number 27:  ['defense', 'organization', 'dod']
# Cluster Size:  60
#
#
# Cluster Number 28:  ['1990', '1980', 'par']
# Cluster Size:  11
#
#
# Cluster Number 29:  ['access', 'dod', 'following']
# Cluster Size:  57
#
#
# Cluster Number 30:  ['defense', 'correspondence', 'office']
# Cluster Size:  37

# %%
clustered_sentences[0]
# Out:
# ['Requesting correct contact for submitting a FOIA to the ARNG Delegated Examining\nUnit in Montgomery, Alabama and the ARNG in the state of Arizona.',
#  'Requesting all contracts held by TCS, Telecommunication Systems (NASDAQ TSYS)\nTCS Headquarters 275 West Street Annapolis MD 21401.',
#  'Requesting all information on case number 4:00CR00547.',
#  'Requesting information regarding Guarani aquifer, better known by its as Spanish name Acuifero Guarani, in DoD records. Requesting records from January 1995 to present.',
#  'Requesting a copy of any and all documents between the USDOD and Pro Technical\nProducts/SupplyCore from 1987 to date.',
#  'Requesting information about records from RRC.',
#  'Request bankruptcy forms, and address where to file bankruptcy forms.',
#  'Request the U.S. government agency that provides U.S. searches to find person, family\nmember address, ect.',
#  'Request U.S. Government Grant Application that is approve to a person in the year of 2005 for personal needs, business, educational and medical needs document.',
#  'Request records of Robert McNamora',
#  'Requesting information on Solicitation # W74V8H04R0027.',
#  'Requesting information on Solicitation # HQ003406APOEDAM1.',
#  'Requesting an electronic copy of the Access database described in job number N1-330- 05-01. Database is described in SF 115 submitted by the OSD as an ACCESS database spreadsheet that is used to locate files for each office of the Coalition Provisional Au..',
#  'Requesting records on project Cosmic Journey.',
#  'Requesting records concerning testing and use of anti-gravity propulsion.',
#  'Requesting information on Social Security procedures.',
#  'Requesting information on goverment policies and procedures concerning AAA credit.',
#  'Searching for incumbent information for Solicitation HQ0034-06-APO-EDAM-1 through\nWHS/ITMD',
#  'Requesting emails, memos, etc.. concerning the massacre of peasant farmers in Augus\nBlancas, in the state of Guerrero',
#  'Request the DoD Birth Defects Registry database and a record layout describing all\ndatabase fields, including withheld fields.',
#  'Requesting all information relating to International Chapter Inc. of Orgeon and its\ninvolvement in Sierra Leone and Liberia from 1995 to present.',
#  'Requesting a copy of the Information Technology Registry Database and any other system of records currently holding similiar information or information once held or currently held in this database. Requests a record layout describing all database fields...',
#  'Requesting information on contracts granted to Thomas James International, Damar Manufacturing, Damar, Machine, Valberg, Cashmere Manufacturing, Recklaw, and\nDouglas Roulstone.',
#  'Requesting audits, complaints or violations involving the following: Thomas James, International, Damar Manufacturing, Damar Machine, Valberg, Cashmere Manufacturing, Recklaw, and Douglas Roulstone.',
#  'Requesting access to ADP customer and card holders Credit Card Holders, GSA Smart\nPay with names.',
#  'Request information of Tricare and Foreign Medical PrograM',
#  'Requesting copies of all direct correspondense between Douglas Roulstone, Thomas James International, Damar Manufacturing, Damar Machine, Valberg, Cashmere Manufacturing, Recklaw and your agency',
#  'Any records',
#  'Requesting the unit mailing addresses for all platoon level and above units for each of\nthe four services',
#  'Requestinga copy of the mailing list under the Fereral Supply Service List for contractors and agencies requesting janitorial and security services. FOIA R05-046- 5FM',
#  'Requesting contacts eligiable for catalogs. F-5-1007',
#  'Requesting all documents, including but not limited to establishing directives, mission statements, organizational charts, personnel information, budget, contracting and controlling regulations, directives, and orders related to the work of the Office of ..',
#  "Requesting all information relating to Woodward Governor Company's facilities in Rock,\nIllinois or Rockton, Illinois from January 1, 2003 to present.",
#  'Request information on roswell report and bluebook operations',
#  'Requesting customer information and mailing list.',
#  'Request all documents relating to abestos in HVAC systems',
#  'Requesting all information on the Information Operations Task Force. Includes establishing directives, mission statements, organizational charts, personnel information, budget, contracting, and controlling regulations, directives, and orders related to t..',
#  'Request a list of all undeliverable assets and/or uncashed checks being held by your\nadministration.',
#  'Referral from GSA. Requesting a list of all govermant offices and indviduals who\nrecieve MarkeTips.',
#  'Referral from GSA. Requesting an electronic version of the GSA Merketips mailing list to include POC Name, Agency Name, Mailing address, Telephone Number, and email\naddress.',
#  'Requesting a copy of the following documents: directors full name that works at the copyright office, the mailing address for the better business bureau office, and a mailing address to a goverment agency that provides goverment grants.',
#  'Requesting information on former Secretaries, former Undersecretaries, former\nAssistant Secretaries etc.',
#  'Requesting information about the Joint Cheifs of Staff including its missions, history and\nbios.',
#  'Requestor is interested in obtaining the following addresses: Walter Reed Army Hospital Bethesda Naval Hospital Foreign Technolgy Divisions Nellis Air Force Base Army C.I.C. Norton Air Force Base Fort Belvoir',
#  'Requesting information and records regarding the past and present use of Depleted\nUranium(DU)',
#  'Requesting all records on TSA No Fly List, all other systems of records',
#  'Requesting information on JMARS.',
#  "Requesting information on the following: The Meadows, Woodridge Hospital, Johnson\nCity Medical Center, East Tennessee State University, University of Tennessee, Landair Transport Inc., Jack Boureson and First Watch International, Greene county Sheriff's D..",
#  'Requesting a list of contacts who are eligable to recieve catalogs undercontract #GS-\n02F-0021R.',
#  'Requesting a mailing list for GSA.',
#  'Requesting Excel spreadsheet, the number os service personnel with Texas listed as\ntheir home of record.',
#  'Requesting information on Solicitation Number FA9451-05-R-0003.',
#  'Request to obtain the most recent enrollment information on contract holders working\nfor the DoD.',
#  'Request a list of all undeliverable monies and/or uncashed checks being held by your\nadministration in any electronic format.',
#  'Requesting information concerning National Security Personnel System (NSPS).',
#  "Requesting information concerning The Battleship Texas Foundation's application.",
#  'Referral from GSA requesting mailing list for VA Medical Facilities.',
#  'Referral from GSA requesting address list for federal goverment agencies relating to\npregnancy tests, drug abuse tests, urine reagent strips and strep tests.',
#  'Referral from GSA requesting mailing list for goverment personnel',
#  'Referral from GSA, requesting mailing list for federal buyers.',
#  'Requesting all information pertaining to the following Venezuelan military: General Manuel Rosendo, General Elicer Hurtado Sucre, General Luis Camacho Kairuz,\nGeneral Enrique Medina Gomez. 20060184DOD016',
#  'Requesting all information pertaining to the following Colombian military officers: Captain Leonidas Munoz, General Carlos Alberto Lemus, General Reynaldo Castellanos. General Luis Alberto Ardila General Hernando Ortiz General Carlos Suarez',
#  'Requesting information on recruiting.',
#  'Requesting information concerning records held at National Archives.',
#  'Requesting information on lost records.',
#  'Requesting records regarding a program at the National Archives to reclassify past\ndocumentation.',
#  'Requesting all correspondence between the Freedom of Information and Security officials and DARPA regarding FOIA Request 03-F-1781 and the administrative appeal.',
#  'Referral from GSA, requesting a list of GSA customers including contact information.',
#  'Requesting information regarding Whitaker-Bermite property and nearby land.\nRequesting records from 1920 to present date.',
#  'Requesting a list of goverment impact credit card holders.',
#  'Referral from GSA. requesting information on personnel who may be involved in\npurchasing 621 I Professional Medical Healthcare Services.',
#  'Requesting a copy of a test taken at a recruiting station in Chicago.',
#  'GSA referral for the request for a list of GSA customers and prospects from the\nCentralized Mailing List Service. GSA is referring the request and records for your decision on disclosure.',
#  'Request information or records on "Studebaker/Black-Eagle" affair.',
#  'Request information or records on a project and/or operation called, "Eagle and Eagle\nII".',
#  'Request information or records on "Hammer".',
#  'Request information or records on the "Five Star Trust".',
#  'Requesting the e-mail and streeet addresses for FOIA officers representing V Corps, Coalition Joint Task Force and Coalition Forces Land Component Command.',
#  'Referral from GSA, requesting mailing list for federal goverment personnel.',
#  'Referral from GSA, requesting contact on federal goverment personnel.',
#  'Requesting contact information for federal government personnel.',
#  'Requesting any information on Rosebud or Rosebu 89.',
#  'Requesting a copy of all documents relating to Blackstar .',
#  'Requesting all documents relating to the television show E-Ring.',
#  'Requesting a list of all BRAC sites that have institutional and/or engineering controls in place, for the entire United States. If possible, wants information on a disk. Provides a list of 35 requested data elements.',
#  'Requesting a list of BRAC site locations for the entire United States. Request listing on disk, cd or by email in Excel, Access, Ascii, text or dbase format. Requester provides eleven requested data elements. Also wants an ArcInfo gis coverage if avail..',
#  'Requesting all documents reporting to Bell UH-1 Series aircraft due to failure of the\nmain rotor mast.',
#  'GSA referral to a request for names, addresses, phone numbers and e-mail addresses of all government personnel that have recently purchased services listed under certain NAIC codes.',
#  'Referral from GSA, requesting a mailing list for Federal Goverment personnel.',
#  'Requesting copies of all standard operating procedures affecting, impacting or controlling the 2005 exercise known as Operation Bright Star conducted in Egypt.',
#  'Requesting the information contained in JMARS on (                        ) and (\n)',
#  'Referral from GSA, requesting mailing list for federal goverment personnel who may be\ninvolved in the purchase of office supplies.',
#  'Requesting full contact information for all Department of Defense Program and or\nProject Manager currently employed.',
#  'Requesting a list of of subject personnel assigned to or employed at the Western Pacific Region to include Los Angeles, Orange and Riverside Counties.',
#  'Requesting a copy of Smart Pay Orders to provide Purchase, Travel and Fleet Card\nservices.',
#  'Requesting information concerning elective surgeries for the United States Marine\nCorps, Army , Navy, and Air Force personnel and their families.',
#  'Request infromation from website www.governmentcontractswon.com , including a\ndescription of its scope of work for TOLTEST, INC',
#  'Request all records',
#  'Requesting information concerning surveilance and monitoring of the Peninsula Peace and Justice Center formerly known as Mid-Peninsula Peace and Justice Center of Palo Alto, California. Request is for records for the period January 1, 1992 to the present..',
#  'Requesting information pertaining to phone calls made to the number 719-721-9592.',
#  'Requesting any records, including awards, grants and financial records relating to David\nTouretzky',
#  'Requesting information about my child Adam Kenneth Tabor in the JAMRS database',
#  'Requesting any and all information concerning Records Manager/Officer for the entire\nDOD, presently and for the past 20 years.',
#  'Requesting to obtain the unit history of the 875th AC&W Squadron based in Rosasa,\nSpain',
#  'Requesting information pertaining to case number 99066.',
#  'Request copies of all records relating to Lt. Col Kanshi Stanley Yamashita during the\nperiod 1942-1992.',
#  'Requesting a list of purpal heart recipients.',
#  'Requesting a list of Impac Cardholders/Purchase Cardholders',
#  'Requesting a list of contracting officers and purchase card holders complete contact list\nincluding email.',
#  'Requesting the files of JCS and OSD for documents relating to the murders and\ndisappearances of women in Ciudad Juarez, Mexico from 1993 to the present.',
#  'Requesting OSD and JCS records relating to the massacre of peasant farmers in\nAguas Blancas, Mexico from 1994 to 1995.',
#  'Requesting OSD and JCS records for information on democratization in Mexico from\n1989-1992.',
#  'Requesting all information pertaining to Charles G. Taylor, the former president of Liberia, including any relationships, formal or informal, with the U.S. Government from\n1982 until the present.',
#  'Requesting information concerning delivery order F01620-03-F-8931.',
#  'Requesting information in reference to the Military Family Housing Maintenance, Transient Aircraft Maintenance Services, Food Services, Rufues and Recycling Services, and Aircraft Washing Services, Fort McNair, Washington D.C.',
#  'Requesting a map of various cities in California as well as data on houses and buildings\nin different cities',
#  'Requesting phone numbers, names, and email addresses of purchases card holders\nwith your agency, pursuant to the Public Records Act',
#  'Requesting copies of any and all documents related to work performed by Asbestos Company of California, Plant ABestos Company, and Plant Insulation Company at any time on or after January 1, 1943',
#  '#NAME?',
#  'Requesting contact information for a manufacturing company attempting to register for\nBid Request consideration.',
#  'Requesting all documents pertaining to the Grade School dog tag ID.',
#  'Referral from OPM requesting the most recent enrollment information on contract\nholders working for the Department of Defense.',
#  'Final agreement for Relocation Services, Solicitation No. W9I2DR-06-R-0020, issued by USAEDBaltimore District, Contracting Division, P.O. Box 1715, Baltimore MD 21203- 1 715, awarded to SIRVA Relocation, LLC on or about June 20, 2006 under a consolidated D..',
#  'I would like to request a list of all the impact credit crd holders that do purchasing of printer parts and supplies I need the name of the person and I would like to request a phone number for each contact.',
#  'i am trying to find out where the school records from the” Frankfurt American High\nSchool” went when it closed in 1995.',
#  'Request a search for records restricted to the Department of State Archiving System, copies of twelve telegrams for the time period of 1/1/1992 and 12/31/1992.',
#  'request for a list of all DoD government purchase card holders/impact card holders.',
#  'records upon which the SOR is based be mailed to the following address:   (\n) and Associates, PLC, 6078 Franconia Road, Suite D, Alexandria, VA 22310-1719',
#  'Requesting names of correctional guards and address to Library of Congress and info\non "grants for writers"',
#  'Request copy of your most recent phone directory or unit directory with office symbols\nand mailiing addresses if possible.']
